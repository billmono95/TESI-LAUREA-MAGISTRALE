# %%
#!pip install yfinance

# %%
import pandas as pd
import yfinance as yf

# %%
from datetime import date

# %%
df = yf.download(
tickers = ["ETH-USD", "BTC-USD","XRP-USD","XLM-USD","LTC-USD","PA=F","GC=F","^GSPC","HSI","^N225","NVDA","AMD"],
start = "2016-01-02",
end = str(date.today()),
interval = "1d"    
)
# Out:
# [*********************100%***********************]  12 of 12 completed

# %%
#df

# %%
df.Close
# Out:
#                   AMD      BTC-USD     ETH-USD         GC=F           HSI  \
# Date
# 2016-01-01        NaN   434.334015    0.948024          NaN           NaN
# 2016-01-02        NaN   433.437988    0.937124          NaN           NaN
# 2016-01-03        NaN   430.010986    0.971905          NaN           NaN
# 2016-01-04   2.770000   433.091003    0.954480  1075.099976  21327.099609
# 2016-01-05   2.750000   431.959991    0.950176  1078.400024  21188.699219
# ...               ...          ...         ...          ...           ...
# 2018-12-28  17.820000  3923.918701  137.647018  1279.900024  25504.199219
# 2018-12-29        NaN  3820.408691  138.018341          NaN           NaN
# 2018-12-30        NaN  3865.952637  139.859451          NaN           NaN
# 2018-12-31  18.459999  3742.700439  133.368256  1278.300049  25845.699219
# 2019-01-01        NaN  3843.520020  140.819412          NaN           NaN
#
#               LTC-USD       NVDA         PA=F   XLM-USD   XRP-USD  \
# Date
# 2016-01-01   3.508980        NaN          NaN  0.001748  0.005955
# 2016-01-02   3.502160        NaN          NaN  0.001741  0.006065
# 2016-01-03   3.483070        NaN          NaN  0.001744  0.006017
# 2016-01-04   3.495390   8.092500   542.950012  0.001748  0.005958
# 2016-01-05   3.469670   8.222500   535.099976  0.001721  0.006044
# ...               ...        ...          ...       ...       ...
# 2018-12-28  32.510830  33.412498  1240.099976  0.121383  0.376852
# 2018-12-29  31.565002        NaN          NaN  0.118036  0.367252
# 2018-12-30  31.976517        NaN          NaN  0.117430  0.369581
# 2018-12-31  30.468224  33.375000  1253.900024  0.112813  0.352706
# 2019-01-01  31.979931        NaN          NaN  0.115930  0.364771
#
#                   ^GSPC         ^N225
# Date
# 2016-01-01          NaN           NaN
# 2016-01-02          NaN           NaN
# 2016-01-03          NaN           NaN
# 2016-01-04  2012.660034  18450.980469
# 2016-01-05  2016.709961  18374.000000
# ...                 ...           ...
# 2018-12-28  2485.739990  20014.769531
# 2018-12-29          NaN           NaN
# 2018-12-30          NaN           NaN
# 2018-12-31  2506.850098           NaN
# 2019-01-01          NaN           NaN
#
# [1097 rows x 12 columns]

# %%
counts = []
for col in df.Close.columns:
    na_count = df.Close[df.Close[col].isna()].shape[0]
    counts.append(na_count)

pd.DataFrame(counts, index=df.Close.columns, columns=['NA'])
# Out:
#           NA
# AMD      343
# BTC-USD    0
# ETH-USD    0
# GC=F     346
# HSI      344
# LTC-USD    0
# NVDA     343
# PA=F     351
# XLM-USD    0
# XRP-USD    0
# ^GSPC    343
# ^N225    359

# %%
df_original = df.Close.copy()

# %%
type(df_original)
# Out:
# pandas.core.frame.DataFrame

# %%
df_original.rename(columns = {'ETH-USD':'ETH', 'BTC-USD':'BTC', 'GC=F':'Gold', 'LTC-USD':'LTC','XLM-USD':'XLM', 'XRP-USD':'XRP','^GSPC':'SP500', '^N225':'N225','PA=F':'Palladium', 'NVDA':'NVIDIA'}, inplace = True)

# %%
df_original.head()
# Out:
#              AMD         BTC       ETH         Gold           HSI      LTC  \
# Date
# 2016-01-01   NaN  434.334015  0.948024          NaN           NaN  3.50898
# 2016-01-02   NaN  433.437988  0.937124          NaN           NaN  3.50216
# 2016-01-03   NaN  430.010986  0.971905          NaN           NaN  3.48307
# 2016-01-04  2.77  433.091003  0.954480  1075.099976  21327.099609  3.49539
# 2016-01-05  2.75  431.959991  0.950176  1078.400024  21188.699219  3.46967
#
#             NVIDIA   Palladium       XLM       XRP        SP500          N225
# Date
# 2016-01-01     NaN         NaN  0.001748  0.005955          NaN           NaN
# 2016-01-02     NaN         NaN  0.001741  0.006065          NaN           NaN
# 2016-01-03     NaN         NaN  0.001744  0.006017          NaN           NaN
# 2016-01-04  8.0925  542.950012  0.001748  0.005958  2012.660034  18450.980469
# 2016-01-05  8.2225  535.099976  0.001721  0.006044  2016.709961  18374.000000

# %%
#df_original = df_original.fillna(method='ffill', inplace=True)

# %%
type(df_original)
# Out:
# pandas.core.frame.DataFrame

# %%
for column_name in df_original.columns:
    df_original[column_name].fillna(method='ffill', inplace=True)
    df_original[column_name].fillna(method='backfill', inplace=True)

# %%
counts = []
for col in df_original.columns:
    na_count = df_original[df_original[col].isna()].shape[0]
    counts.append(na_count)

pd.DataFrame(counts, index=df_original.columns, columns=['NA'])
# Out:
#            NA
# AMD         0
# BTC         0
# ETH         0
# Gold        0
# HSI         0
# LTC         0
# NVIDIA      0
# Palladium   0
# XLM         0
# XRP         0
# SP500       0
# N225        0

# %%
df_original.NVIDIA.head(15)
# Out:
# Date
# 2016-01-01    8.0925
# 2016-01-02    8.0925
# 2016-01-03    8.0925
# 2016-01-04    8.0925
# 2016-01-05    8.2225
# 2016-01-06    7.8825
# 2016-01-07    7.5700
# 2016-01-08    7.4075
# 2016-01-09    7.4075
# 2016-01-10    7.4075
# 2016-01-11    7.4200
# 2016-01-12    7.5450
# 2016-01-13    7.3150
# 2016-01-14    7.1675
# 2016-01-15    6.7775
# Freq: D, Name: NVIDIA, dtype: float64

# %%
df_original.to_csv('data.csv')
