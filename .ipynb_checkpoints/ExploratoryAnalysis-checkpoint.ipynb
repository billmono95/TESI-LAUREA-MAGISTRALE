# %%
import pandas as pd 
import numpy as np
import matplotlib
from scipy.stats.mstats import winsorize

# %%
df = pd.read_csv("file.csv")

# %%
#close price
df.head()
# Out:
#          Date       ETH     BTC       XRP   LTC       XLM  Palladium    Gold  \
# 0  2016-01-01  0.948024  434.33  0.005955  3.51  0.001748     562.00  1060.2
# 1  2016-01-02  0.937124  433.44  0.006065  3.50  0.001741     562.00  1060.2
# 2  2016-01-03  0.971905  430.01  0.006017  3.48  0.001744     562.00  1060.2
# 3  2016-01-04  0.954480  433.09  0.005958  3.50  0.001748     544.20  1075.2
# 4  2016-01-05  0.950176  431.96  0.006044  3.47  0.001721     535.75  1078.4
#
#             HSI          N225   SP500  NVIDIA   AMD
# 0  21914.400391  19033.710938  2035.4   32.96  2.87
# 1  21914.400391  19033.710938  2035.4   32.96  2.87
# 2  21914.400391  19033.710938  2035.4   32.96  2.87
# 3  21327.119141  18450.980469  2009.1   32.37  2.77
# 4  21188.720703  18374.000000  2011.7   32.89  2.75

# %%
# no missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1827 entries, 0 to 1826
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1827 non-null   object
#  1   ETH        1827 non-null   float64
#  2   BTC        1827 non-null   float64
#  3   XRP        1827 non-null   float64
#  4   LTC        1827 non-null   float64
#  5   XLM        1827 non-null   float64
#  6   Palladium  1827 non-null   float64
#  7   Gold       1827 non-null   float64
#  8   HSI        1827 non-null   float64
#  9   N225       1827 non-null   float64
#  10  SP500      1827 non-null   float64
#  11  NVIDIA     1827 non-null   float64
#  12  AMD        1827 non-null   float64
# dtypes: float64(12), object(1)
# memory usage: 185.7+ KB

# %%
df.shape
# Out:
# (1827, 13)

# %%
df.describe()
# Out:
#                ETH           BTC          XRP          LTC          XLM  \
# count  1827.000000   1827.000000  1827.000000  1827.000000  1827.000000
# mean    241.212440   6131.373196     0.288848    57.071834     0.097929
# std     231.644267   4732.385630     0.327973    53.838674     0.117155
# min       0.937124    364.330000     0.005112     3.000000     0.001444
# 25%      46.590000   1187.840000     0.025938     7.360000     0.002868
# 50%     194.870000   6416.310000     0.246065    48.210000     0.067262
# 75%     324.655000   9218.810000     0.335255    73.490000     0.122353
# max    1396.420000  29001.720000     3.380000   358.340000     0.896227
#
#          Palladium         Gold           HSI          N225        SP500  \
# count  1827.000000  1827.000000   1827.000000   1827.000000  1827.000000
# mean   1239.691653  1391.137110  25869.401140  20758.912143  2680.780460
# std     573.601789   218.590348   3084.100808   2512.991016   424.863272
# min     469.800000  1060.200000  18319.580078  14952.019531  1824.500000
# 25%     788.400000  1251.700000  23754.459961  19282.159180  2359.600000
# 50%    1015.200000  1302.900000  26129.929688  21275.919922  2711.100000
# 75%    1619.100000  1487.800000  28187.865235  22594.029297  2941.300000
# max    2711.700000  2069.400000  33154.121094  27568.150391  3712.800000
#
#             NVIDIA          AMD
# count  1827.000000  1827.000000
# mean    200.687849    26.026719
# std     127.314333    22.978505
# min      25.220000     1.800000
# 25%     107.930000    10.920000
# 50%     179.740000    16.270000
# 75%     247.955000    32.720000
# max     582.480000    97.120000

# %% [markdown]
# Descrizione del dataset

# %%
counts = []
for col in df.columns:
    na_count = df[df[col].isna()].shape[0]
    counts.append(na_count)

pd.DataFrame(counts, index=df.columns, columns=['NA'])
# Out:
#            NA
# Date        0
# ETH         0
# BTC         0
# XRP         0
# LTC         0
# XLM         0
# Palladium   0
# Gold        0
# HSI         0
# N225        0
# SP500       0
# NVIDIA      0
# AMD         0

# %% [markdown]
# Check per vedere se sono presenti dati mancanti

# %% [markdown]
# # Prepocessing : trasformazione del tipo di dati

# %%
df.dtypes
# Out:
# Date          object
# ETH          float64
# BTC          float64
# XRP          float64
# LTC          float64
# XLM          float64
# Palladium    float64
# Gold         float64
# HSI          float64
# N225         float64
# SP500        float64
# NVIDIA       float64
# AMD          float64
# dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'],format = "%Y-%m-%d")

# %%
#df.dtypes

# %% [markdown]
# ## Grafici preliminari

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
ax = df.groupby(['date', 'name'])['close'].mean().unstack().plot();
ax.set_ylabel("Price per 1 unit (in USD)");
plt.title("Price per unit of currency");

# %%
#copia del dataset
newdf = df.copy()

# %%
#uso le date come index
newdf.set_index('Date', inplace=True)

# %%
df_cryptocurrencies = newdf[['ETH','BTC','XRP','LTC','XLM']]
df_commodities = newdf[['Palladium','BTC','Gold']]
df_financial_indexes = newdf[['HSI','BTC','N225','SP500']]
df_stock_data = newdf[['NVIDIA','BTC','AMD']]

# %%
list1 = [df_cryptocurrencies,df_commodities,df_financial_indexes,df_stock_data]
list_name = ['Cryptocurrencies', 'Commodities', 'Financial indexes', 'Stock data']
for i in range(len(list1)):
    
    list1[i].plot(figsize=(14,6))
#df_commodities.plot(figsize=(14,6))
    plt.xlabel('Date', fontsize=12)
    plt.ylabel('Price in USD', fontsize=12)
    plt.title('Interest over time '+ list_name[i] + ' with BTC');

# %% [markdown]
# ## Correlazione di Pearson e Kendall

# %%
import seaborn as sns
#pearson correlation
data_corr = newdf.iloc[:, :].corr(method = "pearson")
sns.set(rc={"figure.figsize":(14, 6)})
sns.heatmap(data_corr, annot=True, cmap='Reds')
plt.title("pearson correlation map", fontsize=15)
# Out:
# Text(0.5, 1.0, 'pearson correlation map')

# %%
#kendall correlation
data_corr2 = newdf.iloc[:, :].corr(method = 'kendall')
sns.heatmap(data_corr2, annot=True, cmap="Blues")
plt.title("kendall correlation map", fontsize=15)
# Out:
# Text(0.5, 1.0, 'kendall correlation map')

# %%
#sns.pairplot(newdf)

# %% [markdown]
# ## Grafici: prendo in considerazione solo il 2020

# %%
df_2020 = df[df.Date.dt.year >= 2020]

# %%
#take exam 2020 year
list2 = list(df_2020.columns[1:])
for i in list2:
    df_2020.plot(x='Date', y=i)

# %% [markdown]
# Un trend simile è riportato durante il primo anno di pandemia globale da parte di tutti gli indicatori finanziari

# %%
df_2020.plot(x='Date')
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Grafico che riporta l'andamento dei vari indicatori presenti nel dataset nell' anno 2020.

# %% [markdown]
# ## Returns

# %% [markdown]
# I rendimenti nel mercato delle monete non sono altro che una variazione percentuale del prezzo.

# %%
#faccio una copia del dataset
df_return = newdf.copy()

# %%
#funzione che mi calcola (P1-P0)/P0 il ritorno rispetto al numero di righe specificate nel parametro periods
df_return = df_return.pct_change()

# %%
df_return = df_return.drop(df_return.index[0])

# %%
df_return
# Out:
#                  ETH       BTC       XRP       LTC       XLM  Palladium  \
# Date
# 2016-01-02 -0.011498 -0.002049  0.018472 -0.002849 -0.004005   0.000000
# 2016-01-03  0.037115 -0.007913 -0.007914 -0.005714  0.001723   0.000000
# 2016-01-04 -0.017929  0.007163 -0.009806  0.005747  0.002294  -0.031673
# 2016-01-05 -0.004509 -0.002609  0.014434 -0.008571 -0.015446  -0.015527
# 2016-01-06  0.000720 -0.006598 -0.006784 -0.005764 -0.028472  -0.057303
# ...              ...       ...       ...       ...       ...        ...
# 2020-12-27  0.073603 -0.006232 -0.039611 -0.014985 -0.014104   0.000000
# 2020-12-28  0.069964  0.030927 -0.123944  0.019840 -0.004125   0.002515
# 2020-12-29  0.001533  0.010250 -0.108873 -0.007766 -0.038511  -0.003189
# 2020-12-30  0.027477  0.054034 -0.041337  0.003332 -0.049721   0.014546
# 2020-12-31 -0.018387  0.005574  0.037851 -0.036920 -0.026859   0.031702
#
#                 Gold       HSI      N225     SP500    NVIDIA       AMD
# Date
# 2016-01-02  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2016-01-03  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2016-01-04  0.014148 -0.026799 -0.030616 -0.012921 -0.017900 -0.034843
# 2016-01-05  0.002976 -0.006489 -0.004172  0.001294  0.016064 -0.007220
# 2016-01-06  0.012519 -0.009812 -0.009942 -0.012825 -0.041350 -0.089091
# ...              ...       ...       ...       ...       ...       ...
# 2020-12-27  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2020-12-28 -0.001487 -0.002726  0.007406  0.000000 -0.007215 -0.002287
# 2020-12-29  0.001330  0.009647  0.026593  0.000000  0.003353 -0.010699
# 2020-12-30  0.005577  0.021778 -0.004497  0.000000  0.015645  0.018429
# 2020-12-31  0.000898  0.003095  0.000000  0.000000 -0.006903 -0.006285
#
# [1826 rows x 12 columns]

# %% [markdown]
# ## Grafico dei rendimenti

# %%
list_return = ['ETH','BTC','XRP','LTC','XLM']
for i in list_return:
    
    df_return.plot( y= i , color='#732C2C')

# %%
#df_return.iloc[:, :].corr()
#valori bassi nella correlazione tra return
# Out:
#                 ETH       BTC       XRP       LTC       XLM  Palladium  \
# ETH        1.000000  0.529428  0.318817  0.503567  0.340380   0.071569
# BTC        0.529428  1.000000  0.322589  0.629320  0.372253   0.079646
# XRP        0.318817  0.322589  1.000000  0.386531  0.546971   0.055192
# LTC        0.503567  0.629320  0.386531  1.000000  0.392839   0.043279
# XLM        0.340380  0.372253  0.546971  0.392839  1.000000   0.036841
# Palladium  0.071569  0.079646  0.055192  0.043279  0.036841   1.000000
# Gold       0.081786  0.111552  0.031609  0.049018  0.009983   0.242369
# HSI        0.024886 -0.009399  0.025612  0.021852  0.034632   0.247225
# N225      -0.009203 -0.021633 -0.003855 -0.018825  0.007928   0.247938
# SP500      0.140142  0.154305  0.096221  0.142068  0.104202   0.182410
# NVIDIA     0.120982  0.116921  0.058596  0.100271  0.083315   0.085155
# AMD        0.051791  0.066428  0.045937  0.065835  0.057063   0.096369
#
#                Gold       HSI      N225     SP500    NVIDIA       AMD
# ETH        0.081786  0.024886 -0.009203  0.140142  0.120982  0.051791
# BTC        0.111552 -0.009399 -0.021633  0.154305  0.116921  0.066428
# XRP        0.031609  0.025612 -0.003855  0.096221  0.058596  0.045937
# LTC        0.049018  0.021852 -0.018825  0.142068  0.100271  0.065835
# XLM        0.009983  0.034632  0.007928  0.104202  0.083315  0.057063
# Palladium  0.242369  0.247225  0.247938  0.182410  0.085155  0.096369
# Gold       1.000000 -0.021696 -0.048764  0.008117 -0.018589 -0.016883
# HSI       -0.021696  1.000000  0.514065  0.259831  0.161327  0.105699
# N225      -0.048764  0.514065  1.000000  0.220190  0.108440  0.092219
# SP500      0.008117  0.259831  0.220190  1.000000  0.590880  0.425915
# NVIDIA    -0.018589  0.161327  0.108440  0.590880  1.000000  0.532941
# AMD       -0.016883  0.105699  0.092219  0.425915  0.532941  1.000000

# %%
# Function to detect outliers in every feature
def detect_outliers(dataframe):
    cols = list(dataframe)
    outliers = pd.DataFrame(columns = ['Feature', 'Number of Outliers'])
    for column in cols:
        if column in dataframe.select_dtypes(include=np.number).columns:
            q1 = dataframe[column].quantile(0.25)
            q3 = dataframe[column].quantile(0.75)
            iqr = q3 - q1
            fence_low = q1 - (1.5*iqr)
            fence_high = q3 + (1.5*iqr)
            outliers = outliers.append({'Feature':column, 'Number of Outliers':dataframe.loc[(dataframe[column] < fence_low) | (dataframe[column] > fence_high)].shape[0]},ignore_index=True)
    return outliers

detect_outliers(df_return)
# Out:
#       Feature Number of Outliers
# 0         ETH                157
# 1         BTC                211
# 2         XRP                213
# 3         LTC                183
# 4         XLM                169
# 5   Palladium                246
# 6        Gold                315
# 7         HSI                307
# 8        N225                317
# 9       SP500                389
# 10     NVIDIA                278
# 11        AMD                278

# %% [markdown]
# Numero di outliers presenti in ciascuna feature

# %% [markdown]
# #### Boxplot considerando anche gli outliers

# %%
df_return.boxplot()
# Out:
# <AxesSubplot:>

# %%
#from pandas.plotting import lag_plot
#lag_plot(df_return['BTC'].tail(250))

# %% [markdown]
# Eliminazione degli outliers

# %%
#Function to treat outliers 
def treat_outliers(dataframe):
    cols = list(dataframe)
    for col in cols:
        if col in dataframe.select_dtypes(include=np.number).columns:
            dataframe[col] = winsorize(dataframe[col], limits=[0.05, 0.1],inclusive=(True, True))
    
    return dataframe    


df_return2 = treat_outliers(df_return)

# %%
detect_outliers(df_return2)
# Out:
#       Feature Number of Outliers
# 0         ETH                  0
# 1         BTC                110
# 2         XRP                  0
# 3         LTC                  0
# 4         XLM                  0
# 5   Palladium                136
# 6        Gold                156
# 7         HSI                168
# 8        N225                161
# 9       SP500                389
# 10     NVIDIA                143
# 11        AMD                124

# %% [markdown]
# #### Boxplot senza considerare gli outliers

# %%
df_return2.boxplot()
# Out:
# <AxesSubplot:>
